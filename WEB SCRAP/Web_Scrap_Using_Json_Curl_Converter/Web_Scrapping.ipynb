# %% [markdown]
# # Scrapping truecar.com search_result by Kundan Pawar

# %% [markdown]
# #### Step 1 - Imports

# %%
import requests 
import pandas as pd 
import sqlalchemy
import os

# %% [markdown]
# 1. Go to truecar.com
# 2. Search according to preferences
# 3. When able to see the listings of elements page wise ,
# >  Step1
# >>inspect the page element
# >>>Go to Network->Fetch/XHR
# >>>>Navigate through the pages and clear previous response by "Stop" Symbol

# %% [markdown]
# >find the belonging Name of the resquest by navigating through their Json drop down menu
# >>RTCLK the belonging Name and Copy>Copy_cURL(BASH)
# >>>Go to https://curlconverter.com/ and convert the cURL to cURL python and copy the code
# ## And Paste the code below

# %%
headers = {
    'authority': 'www.truecar.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'en-IN,en;q=0.7',
    # Requests sorts cookies= alphabetically
    # 'cookie': f"flag-abt-tcdc-about-us-page=true; flag-abt-hyundai-ioniq-5-experiment=true; flag-abt-true-car-plus-global-nav-removal=control2; flag-abt-redesigned-ppd=control2; tc_v=d3ebaca5-f5b3-4eaa-816d-d5378f7ad2df; _abp_auth_s=9a_SzkT4KEglhBcrhHY2ifoB8tJ1zNcPbXH2O3wCoVw; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; referrer=ZTC0000000; flag-abt-srp-gql=control2; flag-trade-partner=true; flag-abt-used-cars-lp-price=challenger1; flag-abt-ev-incentives-lp=false; flag-abt-omnisearch-on-tc-plus-landing-page=challenger2; u=rBEAE2McYaZfiQASljW5Ag==; tealium_test_field=Test_C; _fbp=fb.1.1662875740985.780295587; user_zip_code_toronto-ks=66777; capselaPreferredPostalCode=66777; contextHeader=%7B%22header%22%3A%222016%20Honda%20Pilot%20EX%20FWD%22%2C%22image%22%3A%22https%3A%2F%2Flistings-prod.tcimg.net%2Flistings%2F87913%2F03%2F83%2F5FNYF5H38GB058303%2FUX2OGEA4QRRQQ7JQKESODBDEPA-cr-120.jpg%22%2C%22returnUrl%22%3A%22%2Fused-cars-for-sale%2Flisting%2F5FNYF5H38GB058303%2F2016-honda-pilot%2F%22%2C%22returnUrlText%22%3A%22Back%20To%202016%20Honda%20Pilot%20EX%20FWD%22%2C%22subheader%22%3A%22Fair%20Price%20%E2%80%A2%20%2417%2C155%22%7D; tcip=49.42.66.24; utag_main=v_id:01832b1dd7b900482acabb0ea6100406f001806700978{_sn:2$_se:272$_ss:0$_st:1662886099779$dc_visit:2$ses_id:1662878723372%3Bexp-session$_pn:4%3Bexp-session$dc_event:259%3Bexp-session}",
    'if-none-match': 'W/"52db36c6f7181086af53306513cac330"',
    'referer': 'https://www.truecar.com/used-cars-for-sale/listings/price-10000-20000/location-toronto-ks/?page=2',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'sec-gpc': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
}

response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings?city=toronto&collapse=true&fallback=true&include_incentives=true&include_seo\\[\\]=canonicalize_body_styles&include_seo\\[\\]=years&include_seo\\[\\]=inventory_summary&include_seo\\[\\]=faqs&include_targeted_incentives=true&list_price_high=20000&list_price_low=10000&new_or_used=u&per_page=30&postal_code=66777&search_event=true&sort\\[\\]=best_match&sponsored=true&state=ks', headers=headers)
# response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings?city=toronto&collapse=true&fallback=true&include_incentives=true&include_seo\\[\\]=canonicalize_body_styles&include_seo\\[\\]=years&include_seo\\[\\]=inventory_summary&include_seo\\[\\]=faqs&include_targeted_incentives=true&list_price_high=20000&list_price_low=10000&new_or_used=u&  page=2  &per_page=30&postal_code=66777&search_event=true&sort\\[\\]=best_match&sponsored=true&state=ks', headers=headers)

# %% [markdown]
# ## check the status of response we get

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ## Add variable to Json function of the response

# %%
result_json = response.json()

# %% [markdown]
# ## find the drop down keys fo the variable_Of_Json_function

# %%
result_json.keys()
# Out:
# dict_keys(['listings', 'page', 'per_page', 'total', 'fallback', 'fallback_step', 'display', 'list_price', 'buy_online', 'sponsored_listings', 'location'])

# %% [markdown]
# ## check for the drop down container

# %%
result_json['listings']
# Out:
# [{'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'FWD',
#    'engine': '2.5L Inline-4 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 21,
#    'make_slug': 'ford',
#    'make': 'Ford',
#    'model_id': 1068,
#    'model_slug': 'fusion',
#    'model': 'Fusion',
#    'mpg_city': 22,
#    'mpg_combined': 26,
#    'mpg_highway': 34,
#    'style_id': 43840,
#    'style_slug': 'se-fwd',
#    'style': 'SE FWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'se',
#    'trim': 'SE',
#    'trim_id': None,
#    'year': 2014,
#    'chrome_trim_id': 360660,
#    'carfax_report_available': False,
#    'enable_discount': 'no',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '040404',
#    'exterior_color': 'Tuxedo Black Metallic',
#    'exterior_color_id': 646235,
#    'interior_color': 'Ebony',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 646226,
#    'list_price': 12076.0,
# ...

# %% [markdown]
# ## find out if lenght of the drop down container matches the item displayed on Website

# %%
len(result_json['listings'])
# Out:
# 30

# %% [markdown]
# ## make checkpoint variable

# %%
res_item=result_json['listings']

# %% [markdown]
# ## Go for the first element in Dictionary

# %%
result_json['listings'][0]
# Out:
# {'vehicle': {'body_style_slug': 'sedan',
#   'body_style': 'Sedan',
#   'drive_train': 'FWD',
#   'engine': '2.5L Inline-4 Gas',
#   'fuel_type': 'Gas',
#   'make_id': 21,
#   'make_slug': 'ford',
#   'make': 'Ford',
#   'model_id': 1068,
#   'model_slug': 'fusion',
#   'model': 'Fusion',
#   'mpg_city': 22,
#   'mpg_combined': 26,
#   'mpg_highway': 34,
#   'style_id': 43840,
#   'style_slug': 'se-fwd',
#   'style': 'SE FWD',
#   'transmission': 'Automatic',
#   'trim_slug': 'se',
#   'trim': 'SE',
#   'trim_id': None,
#   'year': 2014,
#   'chrome_trim_id': 360660,
#   'carfax_report_available': False,
#   'enable_discount': 'no',
#   'exterior_color_generic': 'Black',
#   'exterior_color_rgb': '040404',
#   'exterior_color': 'Tuxedo Black Metallic',
#   'exterior_color_id': 646235,
#   'interior_color': 'Ebony',
#   'interior_color_generic': 'Black',
#   'interior_color_rgb': '1B1C20',
#   'interior_color_id': 646226,
#   'list_price': 12076.0,
#   'member_discount': 0.0,
# ...

# %% [markdown]
# ## find the relevant key which Column/field we want to fetch

# %%
result_json['listings'][0].keys()
# Out:
# dict_keys(['vehicle', 'dealership', 'payments', 'listed_at', 'distance_retailing', 'images', 'pricing_flags', 'pricing', 'price_curve', 'collapse', 'is_fallback_listing'])

# %% [markdown]
# # vehicle information

# %%
result=result_json['listings'][0]['vehicle']

# %% [markdown]
# # Company information

# %%
result['make']
# Out:
# 'Ford'

# %% [markdown]
# # Model information

# %%
result['model']
# Out:
# 'Fusion'

# %% [markdown]
# # Price information

# %%
result['list_price']
# Out:
# 12076.0

# %% [markdown]
# # Distance_Travelled information

# %%
result['mileage']
# Out:
# 118860

# %% [markdown]
# # Manufecture_Year information

# %%
result['year']
# Out:
# 2014

# %% [markdown]
# # Collect all data of res_item(no. of items in the webpage)

# %%
brand = []
model = []
mileage = []
year = []
price = []


for result in res_item:
    
    # brand
    brand.append(result['vehicle']['make'])
    
    # model
    model.append(result['vehicle']['model'])
    
    # mileage
    mileage.append(result['vehicle']['mileage'])
    
    # year
    year.append(result['vehicle']['year'])
    
    # price
    price.append(result['vehicle']['list_price'])

# %% [markdown]
# # make a pandas DataFrame to print the Records form first Page

# %%
df1=pd.DataFrame({'Brand':brand,'Model':model,'Mileage':mileage,'Year':year,'Price':price})
df1
# Out:
#          Brand           Model  Mileage  Year    Price
# 0         Ford          Fusion   118860  2014  12076.0
# 1         Ford            Edge    90240  2018  16000.0
# 2         Ford          Fusion    31590  2016  18998.0
# 3         Jeep        Wrangler   127650  2012  16990.0
# 4         Jeep         Patriot    69288  2014  15998.0
# 5          Kia           Forte    84136  2017  15998.0
# 6       Nissan          Sentra    43429  2019  19998.0
# 7        Acura             MDX   106347  2012  18998.0
# 8         Jeep  Grand Cherokee    98944  2017  19998.0
# 9        Volvo            XC60   139151  2017  15572.0
# 10        Ford      Expedition   127042  2015  18998.0
# 11     Hyundai          Sonata   120171  2016  14998.0
# 12         Kia           Forte    97607  2015  11649.0
# 13      Nissan          Sentra    53108  2019  19998.0
# 14  Land Rover             LR4   116850  2012  16490.0
# 15      Toyota           Camry    97203  2016  18998.0
# ...

# %% [markdown]
# # now we want to fetch further data from other pages as well i.e from page
# # 2 to 50 and appent them in lists

# %%
brand = []
model = []
mileage = []
year = []
price = []


for i in range(2,50):
    headers = {
        'authority': 'www.truecar.com',
        'accept': 'application/json, text/plain, */*',
        'accept-language': 'en-IN,en;q=0.7',
        # Requests sorts cookies= alphabetically
        # 'cookie': f"flag-abt-tcdc-about-us-page=true; flag-abt-hyundai-ioniq-5-experiment=true; flag-abt-true-car-plus-global-nav-removal=control2; flag-abt-redesigned-ppd=control2; tc_v=d3ebaca5-f5b3-4eaa-816d-d5378f7ad2df; _abp_auth_s=9a_SzkT4KEglhBcrhHY2ifoB8tJ1zNcPbXH2O3wCoVw; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; referrer=ZTC0000000; flag-abt-srp-gql=control2; flag-trade-partner=true; flag-abt-used-cars-lp-price=challenger1; flag-abt-ev-incentives-lp=false; flag-abt-omnisearch-on-tc-plus-landing-page=challenger2; u=rBEAE2McYaZfiQASljW5Ag==; tealium_test_field=Test_C; _fbp=fb.1.1662875740985.780295587; user_zip_code_toronto-ks=66777; capselaPreferredPostalCode=66777; contextHeader=%7B%22header%22%3A%222016%20Honda%20Pilot%20EX%20FWD%22%2C%22image%22%3A%22https%3A%2F%2Flistings-prod.tcimg.net%2Flistings%2F87913%2F03%2F83%2F5FNYF5H38GB058303%2FUX2OGEA4QRRQQ7JQKESODBDEPA-cr-120.jpg%22%2C%22returnUrl%22%3A%22%2Fused-cars-for-sale%2Flisting%2F5FNYF5H38GB058303%2F2016-honda-pilot%2F%22%2C%22returnUrlText%22%3A%22Back%20To%202016%20Honda%20Pilot%20EX%20FWD%22%2C%22subheader%22%3A%22Fair%20Price%20%E2%80%A2%20%2417%2C155%22%7D; tcip=49.42.66.24; utag_main=v_id:01832b1dd7b900482acabb0ea6100406f001806700978{_sn:2$_se:272$_ss:0$_st:1662886099779$dc_visit:2$ses_id:1662878723372%3Bexp-session$_pn:4%3Bexp-session$dc_event:259%3Bexp-session}",
        'if-none-match': 'W/"52db36c6f7181086af53306513cac330"',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/price-10000-20000/location-toronto-ks/?page=2',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'sec-gpc': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
    }

    # response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings?city=toronto&collapse=true&fallback=true&include_incentives=true&include_seo\\[\\]=canonicalize_body_styles&include_seo\\[\\]=years&include_seo\\[\\]=inventory_summary&include_seo\\[\\]=faqs&include_targeted_incentives=true&list_price_high=20000&list_price_low=10000&new_or_used=u&per_page=30&postal_code=66777&search_event=true&sort\\[\\]=best_match&sponsored=true&state=ks', headers=headers)
    URL='https://www.truecar.com/abp/api/vehicles/used/listings?city=toronto&collapse=true&fallback=true&include_incentives=true&include_seo\\[\\]=canonicalize_body_styles&include_seo\\[\\]=years&include_seo\\[\\]=inventory_summary&include_seo\\[\\]=faqs&include_targeted_incentives=true&list_price_high=20000&list_price_low=10000&new_or_used=u&page='+str(i)+'&per_page=30&postal_code=66777&search_event=true&sort\\[\\]=best_match&sponsored=true&state=ks'
#     print(URL)
    response = requests.get(URL, headers=headers)
    
    result_json = response.json()
    result_item=result_json['listings']
    
    for result in result_item:

        # brand
        brand.append(result['vehicle']['make'])

        # model
        model.append(result['vehicle']['model'])

        # mileage
        mileage.append(result['vehicle']['mileage'])

        # year
        year.append(result['vehicle']['year'])

        # price
        price.append(result['vehicle']['list_price'])

# %% [markdown]
# # Now printing all of the data fetched from the 1 to 50 pages in a DataFrame

# %%
df2=pd.DataFrame({'Brand':brand,'Model':model,'Mileage':mileage,'Year':year,'Price':price})
df2
# Out:
#            Brand           Model  Mileage  Year    Price
# 0         Nissan          Armada   121490  2015  19998.0
# 1        Hyundai          Sonata   122443  2012  13599.0
# 2         Nissan          Sentra    44249  2019  19998.0
# 3           Jeep  Grand Cherokee    88649  2014  18990.0
# 4         Toyota         Corolla    51460  2017  19998.0
# ...          ...             ...      ...   ...      ...
# 1435     Hyundai  Santa Fe Sport    58828  2018  19999.0
# 1436         Kia           Forte   108958  2020  18998.0
# 1437      Nissan           Rogue   104231  2016  17998.0
# 1438         Kia          Optima    56541  2016  19998.0
# 1439  Volkswagen           Jetta    89761  2016  16998.0
#
# [1440 rows x 5 columns]

# %% [markdown]
# # checking for individual field

# %%
brand
# Out:
# ['Nissan',
#  'Hyundai',
#  'Nissan',
#  'Jeep',
#  'Toyota',
#  'Ford',
#  'Nissan',
#  'Ford',
#  'Nissan',
#  'Kia',
#  'Cadillac',
#  'Chevrolet',
#  'Toyota',
#  'Nissan',
#  'Nissan',
#  'Ford',
#  'Ford',
#  'Nissan',
#  'Honda',
#  'Jeep',
#  'Hyundai',
#  'Honda',
#  'Ford',
#  'Kia',
#  'Hyundai',
#  'Chevrolet',
#  'Nissan',
#  'Ford',
#  'Nissan',
#  'Nissan',
#  'Kia',
#  'Ford',
#  'Chevrolet',
#  'Nissan',
#  'Ford',
#  'Toyota',
#  'Nissan',
#  'Nissan',
#  'Ford',
#  'Nissan',
#  'Nissan',
#  'Jeep',
#  'Kia',
#  'Kia',
#  'Kia',
#  'Toyota',
#  'Nissan',
#  'BMW',
#  'Honda',
#  'Jeep',
#  'Nissan',
#  'Nissan',
#  'Volkswagen',
#  'GMC',
#  'Ford',
#  'Toyota',
#  'Hyundai',
#  'Toyota',
#  'Chevrolet',
#  'Chevrolet',
#  'Kia',
#  'Jeep',
#  'Jeep',
#  'BMW',
#  'Chevrolet',
#  'Hyundai',
#  'Scion',
#  'Lexus',
#  'Ford',
#  'Toyota',
#  'Ford',
#  'Kia',
#  'Kia',
#  'Volvo',
#  'Jeep',
#  'Toyota',
#  'Honda',
#  'Chevrolet',
#  'Ford',
#  'Chevrolet',
# ...

# %% [markdown]
# ## Connect to Database - PostgreSQL

# %%
# pip install sqlalchemy
# pip install PyMySQL

# %%
# install postgras on comuputer - pdadmin is UI based Application to run SQL wueries

# %%
# password : "password"

# %%
# create sqlalchemy engine
# engine = sqlalchemy.create_engine('postgresql://postgres:Scaleop7@localhost:5432')
